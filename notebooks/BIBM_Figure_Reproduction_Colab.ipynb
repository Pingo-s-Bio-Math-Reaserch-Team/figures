# %% [markdown]
# # BIBM Figure Reproduction Notebook
#
# Upload or mount the `bibm_figure_reproducibility` folder in Google Colab, then run these cells. The notebook regenerates all figures from bundled CSV source tables. It does not hard-code manuscript results.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Change this path to wherever you placed the package in Drive.
PROJECT_DIR = '/content/drive/MyDrive/bibm_figure_reproducibility'

# %%
# !pip install -q numpy pandas matplotlib scipy scikit-learn lifelines

# %%
import os
os.chdir(PROJECT_DIR)
# !python scripts/verify_results_from_tables.py

# %%
# !python scripts/reproduce_all_figures.py

# %% [markdown]
# Generated figures are saved in `figures/` as both PDF and PNG at high resolution. Use the PDF versions for LaTeX whenever possible.
